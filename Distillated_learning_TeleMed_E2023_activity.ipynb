# %% [markdown]
# <a href="https://colab.research.google.com/github/Lizzie-MH/IA-class/blob/main/Distillated_learning_TeleMed_E2023_activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Dataset download
import os 

if 'file_downloaded' not in os.listdir():
  print('Se descargara la base de datos')
  # !wget https://data.mendeley.com/public-files/datasets/rscbjbr9sj/files/f12eaf6d-6023-432f-acc9-80c9d7393433/file_downloaded

if 'chest_xray' not in os.listdir():
  print('Se descomprimira la base de datos')
  # !unzip file_downloaded

# %%
#@title Workspace definition and GPU info
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)

# Check RAM
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))
# Out:
# Wed May 17 18:44:16 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Your runtime has 13.6 gigabytes of available RAM

# %%
#@title Import standard libraries

import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from PIL import Image as im

# %%
#@title Import ML libraries

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, Dropout, MaxPool2D, BatchNormalization, Input, Conv2DTranspose, Concatenate
from tensorflow.keras.losses import SparseCategoricalCrossentropy, CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#@title Dataset exploration

train_path = 'chest_xray/train'
fig = plt.figure(figsize=(15,6))

for i, folder in enumerate(os.listdir(train_path)):
    if str(folder).startswith("."): continue
    for j, img in enumerate(os.listdir(train_path+"/"+folder)):
        
        if (4*i)+j+1 > 8: break 
        
        filename = train_path+"/"+folder + "/" + img
        img= im.open(filename)
        ax = plt.subplot(2,4,(4*i)+j+1)
        ax.set_xlabel(folder+ ' '+ str(img.size[0]) +'x'+ str(img.size[1]))
        plt.imshow(img, 'gray')
        ax.set_xlabel(folder+ ' '+ str(img.size[0]) +'x'+ str(img.size[1]))
        ax.axes.xaxis.set_ticklabels([])
        ax.axes.yaxis.set_ticklabels([])
        #plt.axis('off')
        img.close()
        if j>2:
            break

# %%
#@title Image generators definition

def trainGenerator(batch_size, train_path):
    datagen = ImageDataGenerator(rescale=1. / 255, rotation_range=5, shear_range=0.02, zoom_range=0.1,
                                       brightness_range=[0.7,1.3],  horizontal_flip=True,
                                         vertical_flip=True, fill_mode='nearest')
    
    train_gen = datagen.flow_from_directory(train_path, batch_size=batch_size,target_size=(224, 224), 
                                            shuffle=True, seed=1, class_mode="categorical" )
    for image, label in train_gen:
        yield (image, label)

def validGenerator(batch_size, valid_path):
  datagen = ImageDataGenerator(rescale=1. / 255, )
  
  valid_gen = datagen.flow_from_directory(valid_path, batch_size=batch_size, target_size=(224, 224),
                                          shuffle=True, seed=1, class_mode="categorical" )
  for image, label in valid_gen:
    yield (image, label)

# %%
#@title Main model architecture
from tensorflow.keras.applications.vgg16 import VGG16

base_model = VGG16(input_shape = (224, 224, 3), 
                   include_top = False, 
                   weights = 'imagenet')

for layer in base_model.layers[:8]:
  layer.trainable = False

x = layers.Flatten()(base_model.output)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(2)(x) 


model = tf.keras.models.Model(base_model.input, x)
opti = Adam(learning_rate=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
model.compile(optimizer = opti, loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True), metrics='acc')
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 512)               12845568
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 27,561,282
# Trainable params: 27,005,954
# Non-trainable params: 555,328
# _________________________________________________________________

# %%
#@title Main model training
train_generator = trainGenerator(64,'chest_xray/train')
validation_generator = validGenerator(16,'chest_xray/test')

earlystop = EarlyStopping(monitor='val_acc', patience=5, verbose=1)
filepath="model_save/weights-{epoch:02d}-{val_accuracy:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks = [earlystop ]
vgg_hist = model.fit(train_generator, validation_data = validation_generator, validation_steps=10, 
                    steps_per_epoch = 64, epochs = 20, callbacks=callbacks)
# Out:
# Found 5232 images belonging to 2 classes.
# Epoch 1/20
# 64/64 [==============================] - ETA: 0s - loss: 0.2834 - acc: 0.8745Found 624 images belonging to 2 classes.
# 64/64 [==============================] - 126s 2s/step - loss: 0.2834 - acc: 0.8745 - val_loss: 0.2492 - val_acc: 0.9062
# Epoch 2/20
# 64/64 [==============================] - 109s 2s/step - loss: 0.1365 - acc: 0.9461 - val_loss: 0.4673 - val_acc: 0.8438
# Epoch 3/20
# 64/64 [==============================] - 111s 2s/step - loss: 0.1606 - acc: 0.9400 - val_loss: 0.2990 - val_acc: 0.8813
# Epoch 4/20
# 64/64 [==============================] - 102s 2s/step - loss: 0.1219 - acc: 0.9549 - val_loss: 0.2801 - val_acc: 0.9250
# Epoch 5/20
# 64/64 [==============================] - 120s 2s/step - loss: 0.1108 - acc: 0.9587 - val_loss: 0.9847 - val_acc: 0.7750
# Epoch 6/20
# 64/64 [==============================] - 103s 2s/step - loss: 0.0932 - acc: 0.9645 - val_loss: 0.2560 - val_acc: 0.9250
# Epoch 7/20
# 64/64 [==============================] - 100s 2s/step - loss: 0.0953 - acc: 0.9642 - val_loss: 0.5132 - val_acc: 0.8188
# Epoch 8/20
# 64/64 [==============================] - 99s 2s/step - loss: 0.0659 - acc: 0.9762 - val_loss: 0.5865 - val_acc: 0.8750
# Epoch 9/20
# 64/64 [==============================] - 101s 2s/step - loss: 0.0651 - acc: 0.9750 - val_loss: 0.3202 - val_acc: 0.9125
# Epoch 9: early stopping

# %%
#@title Main model metrics evolution

plt.figure(1)  
# summarize history for accuracy
plt.subplot(211)
plt.plot(vgg_hist.history['acc'])
plt.plot(vgg_hist.history['val_acc'])
plt.title('teacher model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='lower right')
 # summarize history for loss
plt.subplot(212)
plt.plot(vgg_hist.history['loss'])
plt.plot(vgg_hist.history['val_loss'])
plt.title('teacher model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper right')
plt.show()

# %%
#@title Model assessment

from sklearn.datasets import load_files
import numpy as np
test_dir = 'chest_xray/test'
no_of_classes = 2
def load_dataset(path):
    data = load_files(path)
    files = np.array(data['filenames'])
    targets = np.array(data['target'])
    target_labels = np.array(data['target_names'])
    return files,targets,target_labels
x_test, y_test,target_labels = load_dataset(test_dir)
from keras.utils import np_utils
y_test = np_utils.to_categorical(y_test,no_of_classes)
# We just have the file names in the x set. Let's load the images and convert them into array.

from tensorflow.keras.utils import array_to_img, img_to_array, load_img

def convert_image_to_array(files):
    images_as_array=[]
    for file in files:
        # Convert to Numpy Array
        images_as_array.append(tf.image.resize(img_to_array(load_img(file)), (224, 224)))
    return images_as_array

x_test = np.array(convert_image_to_array(x_test))
print('Test set shape : ',x_test.shape)
x_test = x_test.astype('float32')/255
# Let's visualize test prediction.
y_pred_logits = model.predict(x_test)
y_pred = tf.nn.softmax(y_pred_logits)

# plot a raandom sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(16, 9))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=16, replace=False)):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_pred[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(target_labels[pred_idx], target_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
# Out:
# Test set shape :  (624, 224, 224, 3)
# 20/20 [==============================] - 7s 115ms/step

# %%
#@title Main model metrics

print(model.metrics_names) 
loss, acc = model.evaluate(x_test, y_test, verbose = 1)
print('test loss = ', loss) 
print('test accuracy = ',acc)
# Out:
# ['loss', 'acc']
# 20/20 [==============================] - 3s 123ms/step - loss: 0.3280 - acc: 0.8974
# test loss =  0.3280426561832428
# test accuracy =  0.8974359035491943

# %%
#@title Reduced model definition

# input
input = layers.Input(shape =(224,224,3))
# 1st Conv Block
x = layers.Conv2D (filters =8, kernel_size =3, padding ='valid', activation='relu')(input)
x = layers.Conv2D (filters =8, kernel_size =3, padding ='valid', activation='relu')(x)
x = layers.MaxPool2D(pool_size =2, strides =2, padding ='valid')(x)
# 2nd Conv Block
x = layers.Conv2D (filters =16, kernel_size =3, padding ='valid', activation='relu')(x)
x = layers.Conv2D (filters =16, kernel_size =3, padding ='valid', activation='relu')(x)
x = layers.MaxPool2D(pool_size =2, strides =2, padding ='valid')(x)
# 3rd Conv block
x = layers.Conv2D (filters =32, kernel_size =3, padding ='valid', activation='relu')(x)
x = layers.Conv2D (filters =32, kernel_size =3, padding ='valid', activation='relu')(x)
x = layers.MaxPool2D(pool_size =2, strides =2, padding ='valid')(x)
# 4th Conv block
x = layers.Conv2D (filters =64, kernel_size =3, padding ='valid', activation='relu')(x)
x = layers.Conv2D (filters =64, kernel_size =3, padding ='valid', activation='relu')(x)
x = layers.MaxPool2D(pool_size =2, strides =2, padding ='valid')(x)
# 5th Conv block
x = layers.Conv2D (filters =64, kernel_size =3, padding ='valid', activation='relu')(x)
x = layers.Conv2D (filters =64, kernel_size =3, padding ='valid', activation='relu')(x)
x = layers.MaxPool2D(pool_size =2, strides =2, padding ='valid')(x)
# Fully connected layers
x = layers.Flatten()(x)
x = layers.Dense(units = 256, activation ='relu')(x)
x = layers.Dropout(0.5)(x)
output = layers.Dense(units = 2)(x)

# %%
#@title Reduced model architecture

reduced_model = Model(inputs=input, outputs=output)
reduced_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 222, 222, 8)       224
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 8)       584
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 8)      0
#  )
#
#  conv2d_2 (Conv2D)           (None, 108, 108, 16)      1168
#
#  conv2d_3 (Conv2D)           (None, 106, 106, 16)      2320
#
#  max_pooling2d_1 (MaxPooling  (None, 53, 53, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 51, 51, 32)        4640
#
#  conv2d_5 (Conv2D)           (None, 49, 49, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 24, 24, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 22, 22, 64)        18496
#
#  conv2d_7 (Conv2D)           (None, 20, 20, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 64)          36928
#
#  conv2d_9 (Conv2D)           (None, 6, 6, 64)          36928
#
#  max_pooling2d_4 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 576)               0
#
#  dense_2 (Dense)             (None, 256)               147712
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 295,690
# Trainable params: 295,690
# Non-trainable params: 0
# _________________________________________________________________

# %%
#@title Reduced model training

opti = Adam(learning_rate=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08) # , decay=0.001)
reduced_model.compile(optimizer = opti, loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True),metrics = ['acc'])
earlystop = EarlyStopping(monitor='val_acc', patience=5, verbose=1)
filepath="model_save/weights-{epoch:02d}-{val_accuracy:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks = [earlystop ]
reduced_modelhist = reduced_model.fit(train_generator, validation_data = validation_generator, validation_steps=10,
                    steps_per_epoch = 64, epochs = 20, callbacks=callbacks)
# Out:
# Epoch 1/20
# 64/64 [==============================] - 99s 1s/step - loss: 0.6099 - acc: 0.7388 - val_loss: 0.6478 - val_acc: 0.6562
# Epoch 2/20
# 64/64 [==============================] - 94s 1s/step - loss: 0.5715 - acc: 0.7358 - val_loss: 0.6703 - val_acc: 0.5562
# Epoch 3/20
# 64/64 [==============================] - 92s 1s/step - loss: 0.4046 - acc: 0.8054 - val_loss: 0.3874 - val_acc: 0.8062
# Epoch 4/20
# 64/64 [==============================] - 90s 1s/step - loss: 0.3461 - acc: 0.8422 - val_loss: 0.4614 - val_acc: 0.7812
# Epoch 5/20
# 64/64 [==============================] - 91s 1s/step - loss: 0.3006 - acc: 0.8704 - val_loss: 0.4571 - val_acc: 0.7625
# Epoch 6/20
# 64/64 [==============================] - 91s 1s/step - loss: 0.2928 - acc: 0.8706 - val_loss: 0.3256 - val_acc: 0.8500
# Epoch 7/20
# 64/64 [==============================] - 93s 1s/step - loss: 0.2821 - acc: 0.8760 - val_loss: 0.4148 - val_acc: 0.8562
# Epoch 8/20
# 64/64 [==============================] - 91s 1s/step - loss: 0.2633 - acc: 0.8929 - val_loss: 0.3034 - val_acc: 0.8562
# Epoch 9/20
# 64/64 [==============================] - 91s 1s/step - loss: 0.2541 - acc: 0.8890 - val_loss: 0.4113 - val_acc: 0.8125
# Epoch 10/20
# 64/64 [==============================] - 92s 1s/step - loss: 0.2385 - acc: 0.9011 - val_loss: 0.3633 - val_acc: 0.8500
# Epoch 11/20
# 64/64 [==============================] - 92s 1s/step - loss: 0.2347 - acc: 0.9051 - val_loss: 0.2926 - val_acc: 0.8813
# Epoch 12/20
# 64/64 [==============================] - 94s 1s/step - loss: 0.2156 - acc: 0.9145 - val_loss: 0.3279 - val_acc: 0.8625
# Epoch 13/20
# 64/64 [==============================] - 91s 1s/step - loss: 0.2135 - acc: 0.9100 - val_loss: 0.3075 - val_acc: 0.8938
# Epoch 14/20
# 64/64 [==============================] - 94s 1s/step - loss: 0.1934 - acc: 0.9189 - val_loss: 0.5020 - val_acc: 0.8125
# Epoch 15/20
# 64/64 [==============================] - 92s 1s/step - loss: 0.2009 - acc: 0.9238 - val_loss: 0.4099 - val_acc: 0.8375
# Epoch 16/20
# 64/64 [==============================] - 94s 1s/step - loss: 0.1913 - acc: 0.9262 - val_loss: 0.3012 - val_acc: 0.8813
# Epoch 17/20
# 64/64 [==============================] - 92s 1s/step - loss: 0.1978 - acc: 0.9208 - val_loss: 0.4128 - val_acc: 0.8625
# Epoch 18/20
# 64/64 [==============================] - 95s 1s/step - loss: 0.1737 - acc: 0.9377 - val_loss: 0.3918 - val_acc: 0.8375
# Epoch 18: early stopping

# %%
#@title Reduced model metrics evaluation

plt.figure(1)  
# summarize history for accuracy  
plt.subplot(211)  
plt.plot(reduced_modelhist.history['acc'])  
plt.plot(reduced_modelhist.history['val_acc'])  
plt.title('model accuracy')  
plt.ylabel('accuracy')  
plt.xlabel('epoch')  
plt.legend(['train', 'valid'], loc='lower right')  
 # summarize history for loss  
plt.subplot(212)  
plt.plot(reduced_modelhist.history['loss'])  
plt.plot(reduced_modelhist.history['val_loss'])  
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'valid'], loc='upper right')  
plt.tight_layout()
plt.show()

# %%
#@title Reduced model metrics

print(reduced_model.metrics_names)
loss, acc = reduced_model.evaluate(x_test, y_test, verbose = 1)
print('test loss = ', loss)
print('test accuracy = ',acc)
# Out:
# ['loss', 'acc']
# 20/20 [==============================] - 1s 16ms/step - loss: 0.3717 - acc: 0.8494
# test loss =  0.3717029392719269
# test accuracy =  0.8493589758872986

# %% [markdown]
# # Modelo estudiante

# %%
#@title Student model definition 

student_model = Model(inputs=input, outputs=output)
student_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 222, 222, 8)       224
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 8)       584
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 8)      0
#  )
#
#  conv2d_2 (Conv2D)           (None, 108, 108, 16)      1168
#
#  conv2d_3 (Conv2D)           (None, 106, 106, 16)      2320
#
#  max_pooling2d_1 (MaxPooling  (None, 53, 53, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 51, 51, 32)        4640
#
#  conv2d_5 (Conv2D)           (None, 49, 49, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 24, 24, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 22, 22, 64)        18496
#
#  conv2d_7 (Conv2D)           (None, 20, 20, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 64)          36928
#
#  conv2d_9 (Conv2D)           (None, 6, 6, 64)          36928
#
#  max_pooling2d_4 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 576)               0
#
#  dense_2 (Dense)             (None, 256)               147712
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 295,690
# Trainable params: 295,690
# Non-trainable params: 0
# _________________________________________________________________

# %%
#@title Destiler definition 

import keras
class Distiller(keras.Model):
    def __init__(self, student, teacher):
        # super(Distiller, self).__init__()
        super().__init__()
        self.teacher = teacher
        self.student = student
    def compile(
        self,
        optimizer,
        metrics,
        student_loss_fn,
        distillation_loss_fn,
        alpha=0.5,
        temperature=2,
    ):
        """ Configure the distiller.
        Args:
            optimizer: Keras optimizer for the student weights
            metrics: Keras metrics for evaluation
            student_loss_fn: Loss function of difference between student
                predictions and ground-truth
            distillation_loss_fn: Loss function of difference between soft
                student predictions and soft teacher predictions
            alpha: weight to student_loss_fn and 1-alpha to distillation_loss_fn
            temperature: Temperature for softening probability distributions.
                Larger temperature gives softer distributions.
        """
        # super(Distiller, self).compile(optimizer=optimizer, metrics=metrics)
        super().compile(optimizer=optimizer, metrics=metrics)
        self.student_loss_fn = student_loss_fn
        self.distillation_loss_fn = distillation_loss_fn
        self.alpha = alpha
        self.temperature = temperature
    def train_step(self, data):
        # Unpack data
        x, y = data
        # Forward pass of teacher
        teacher_predictions = self.teacher(x, training=False)
        
        with tf.GradientTape() as tape:
            # Forward pass of student
            student_predictions = self.student(x, training=True)

            # Compute losses
            student_loss = self.student_loss_fn(y, student_predictions)
            
            distillation_loss = self.distillation_loss_fn(
                tf.nn.softmax(teacher_predictions / self.temperature, axis=1),
                tf.nn.softmax(student_predictions / self.temperature, axis=1),
            )
            loss = self.alpha * student_loss +  distillation_loss
        # Compute gradients
        trainable_vars = self.student.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))
        # Update the metrics configured in `compile()`.
        self.compiled_metrics.update_state(y, student_predictions)
        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update(
            {"student_loss": student_loss, "distillation_loss": distillation_loss}
        )
        return results
    def test_step(self, data):
        # Unpack the data
        x, y = data
        # Compute predictions
        y_prediction = self.student(x, training=False)
        # Calculate the loss
        student_loss = self.student_loss_fn(y, y_prediction)
        # Update the metrics.
        self.compiled_metrics.update_state(y, y_prediction)
        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update({"student_loss": student_loss})
        return results

# %%
#@title Destiled model training

# Initialize and compile distiller
distiller = Distiller(student=student_model, teacher=model)
distiller.compile(
    optimizer=Adam(learning_rate=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08), # , decay=0.001),
    metrics=['acc'],
    student_loss_fn=CategoricalCrossentropy(from_logits=True),
    #distillation_loss_fn=CategoricalCrossentropy(), 
    distillation_loss_fn=tf.keras.losses.KLDivergence(),
    alpha=0.5,
    temperature=6,
)
# Distill teacher to student
distiller_hist = distiller.fit(train_generator, validation_data = validation_generator, epochs=50, validation_steps=10,
              steps_per_epoch = 64)
# Out:
# Epoch 1/50
# 64/64 [==============================] - 99s 1s/step - acc: 0.9678 - student_loss: 0.0891 - distillation_loss: 0.0187 - val_acc: 0.8438 - val_student_loss: 0.7209
# Epoch 2/50
# 64/64 [==============================] - 93s 1s/step - acc: 0.9681 - student_loss: 0.0889 - distillation_loss: 0.0178 - val_acc: 0.8813 - val_student_loss: 0.4091
# Epoch 3/50
# 64/64 [==============================] - 95s 2s/step - acc: 0.9647 - student_loss: 0.0955 - distillation_loss: 0.0188 - val_acc: 0.8938 - val_student_loss: 0.6737
# Epoch 4/50
# 64/64 [==============================] - 95s 1s/step - acc: 0.9684 - student_loss: 0.0893 - distillation_loss: 0.0196 - val_acc: 0.8500 - val_student_loss: 0.3794
# Epoch 5/50
# 64/64 [==============================] - 93s 1s/step - acc: 0.9615 - student_loss: 0.0920 - distillation_loss: 0.0189 - val_acc: 0.8875 - val_student_loss: 0.1079
# Epoch 6/50
# 64/64 [==============================] - 94s 1s/step - acc: 0.9690 - student_loss: 0.0839 - distillation_loss: 0.0184 - val_acc: 0.8750 - val_student_loss: 0.3208
# Epoch 7/50
# 64/64 [==============================] - 94s 1s/step - acc: 0.9708 - student_loss: 0.0747 - distillation_loss: 0.0174 - val_acc: 0.9062 - val_student_loss: 0.1299
# Epoch 8/50
# 64/64 [==============================] - 95s 2s/step - acc: 0.9608 - student_loss: 0.1035 - distillation_loss: 0.0212 - val_acc: 0.8438 - val_student_loss: 0.9601
# Epoch 9/50
# 64/64 [==============================] - 95s 1s/step - acc: 0.9684 - student_loss: 0.0854 - distillation_loss: 0.0190 - val_acc: 0.9125 - val_student_loss: 0.0297
# Epoch 10/50
# 64/64 [==============================] - 97s 2s/step - acc: 0.9683 - student_loss: 0.0837 - distillation_loss: 0.0172 - val_acc: 0.8813 - val_student_loss: 0.3486
# Epoch 11/50
# 64/64 [==============================] - 94s 1s/step - acc: 0.9706 - student_loss: 0.0769 - distillation_loss: 0.0170 - val_acc: 0.8625 - val_student_loss: 0.9062
# Epoch 12/50
# 64/64 [==============================] - 94s 1s/step - acc: 0.9691 - student_loss: 0.0861 - distillation_loss: 0.0173 - val_acc: 0.9187 - val_student_loss: 0.2580
# Epoch 13/50
# 64/64 [==============================] - 94s 1s/step - acc: 0.9706 - student_loss: 0.0801 - distillation_loss: 0.0192 - val_acc: 0.8438 - val_student_loss: 0.0807
# Epoch 14/50
# 64/64 [==============================] - 94s 1s/step - acc: 0.9669 - student_loss: 0.0883 - distillation_loss: 0.0168 - val_acc: 0.8250 - val_student_loss: 0.5331
# Epoch 15/50
# 64/64 [==============================] - 94s 1s/step - acc: 0.9697 - student_loss: 0.0829 - distillation_loss: 0.0166 - val_acc: 0.9250 - val_student_loss: 0.2504
# Epoch 16/50
# 64/64 [==============================] - 94s 1s/step - acc: 0.9706 - student_loss: 0.0843 - distillation_loss: 0.0170 - val_acc: 0.8375 - val_student_loss: 0.8196
# Epoch 17/50
# 64/64 [==============================] - 93s 1s/step - acc: 0.9657 - student_loss: 0.0812 - distillation_loss: 0.0171 - val_acc: 0.8813 - val_student_loss: 0.4074
# Epoch 18/50
# 64/64 [==============================] - 94s 1s/step - acc: 0.9711 - student_loss: 0.0769 - distillation_loss: 0.0182 - val_acc: 0.9062 - val_student_loss: 0.2564
# Epoch 19/50
# 64/64 [==============================] - 93s 1s/step - acc: 0.9686 - student_loss: 0.0889 - distillation_loss: 0.0182 - val_acc: 0.8938 - val_student_loss: 0.1345
# Epoch 20/50
# 64/64 [==============================] - 94s 1s/step - acc: 0.9695 - student_loss: 0.0801 - distillation_loss: 0.0181 - val_acc: 0.9000 - val_student_loss: 0.0119
# Epoch 21/50
# 64/64 [==============================] - 94s 1s/step - acc: 0.9669 - student_loss: 0.0836 - distillation_loss: 0.0179 - val_acc: 0.8938 - val_student_loss: 0.6161
# Epoch 22/50
# 64/64 [==============================] - 93s 1s/step - acc: 0.9735 - student_loss: 0.0777 - distillation_loss: 0.0156 - val_acc: 0.8375 - val_student_loss: 0.5302
# Epoch 23/50
# 64/64 [==============================] - 95s 1s/step - acc: 0.9716 - student_loss: 0.0775 - distillation_loss: 0.0164 - val_acc: 0.8625 - val_student_loss: 0.6889
# Epoch 24/50
# 64/64 [==============================] - 94s 1s/step - acc: 0.9717 - student_loss: 0.0771 - distillation_loss: 0.0159 - val_acc: 0.9375 - val_student_loss: 0.0079
# Epoch 25/50
# 64/64 [==============================] - 95s 2s/step - acc: 0.9721 - student_loss: 0.0754 - distillation_loss: 0.0173 - val_acc: 0.8938 - val_student_loss: 0.1914
# Epoch 26/50
# 64/64 [==============================] - 95s 2s/step - acc: 0.9740 - student_loss: 0.0720 - distillation_loss: 0.0167 - val_acc: 0.8375 - val_student_loss: 0.3644
# Epoch 27/50
# 64/64 [==============================] - 94s 1s/step - acc: 0.9711 - student_loss: 0.0758 - distillation_loss: 0.0171 - val_acc: 0.9187 - val_student_loss: 0.2941
# Epoch 28/50
# 64/64 [==============================] - 94s 1s/step - acc: 0.9728 - student_loss: 0.0750 - distillation_loss: 0.0162 - val_acc: 0.9000 - val_student_loss: 0.5490
# Epoch 29/50
# 64/64 [==============================] - 97s 2s/step - acc: 0.9705 - student_loss: 0.0746 - distillation_loss: 0.0163 - val_acc: 0.9125 - val_student_loss: 0.4304
# Epoch 30/50
# 64/64 [==============================] - 95s 2s/step - acc: 0.9733 - student_loss: 0.0726 - distillation_loss: 0.0167 - val_acc: 0.9062 - val_student_loss: 0.0659
# Epoch 31/50
# 64/64 [==============================] - 95s 1s/step - acc: 0.9730 - student_loss: 0.0683 - distillation_loss: 0.0170 - val_acc: 0.9125 - val_student_loss: 0.4518
# Epoch 32/50
# 64/64 [==============================] - 96s 2s/step - acc: 0.9703 - student_loss: 0.0727 - distillation_loss: 0.0172 - val_acc: 0.9312 - val_student_loss: 0.0575
# Epoch 33/50
# 64/64 [==============================] - 95s 1s/step - acc: 0.9673 - student_loss: 0.0880 - distillation_loss: 0.0169 - val_acc: 0.8938 - val_student_loss: 0.0781
# Epoch 34/50
# 64/64 [==============================] - 95s 1s/step - acc: 0.9725 - student_loss: 0.0763 - distillation_loss: 0.0160 - val_acc: 0.9000 - val_student_loss: 0.0046
# Epoch 35/50
# 64/64 [==============================] - 96s 2s/step - acc: 0.9745 - student_loss: 0.0735 - distillation_loss: 0.0158 - val_acc: 0.8875 - val_student_loss: 0.4651
# Epoch 36/50
# 64/64 [==============================] - 94s 1s/step - acc: 0.9723 - student_loss: 0.0763 - distillation_loss: 0.0163 - val_acc: 0.8500 - val_student_loss: 0.9619
# Epoch 37/50
# 64/64 [==============================] - 97s 2s/step - acc: 0.9728 - student_loss: 0.0771 - distillation_loss: 0.0161 - val_acc: 0.9000 - val_student_loss: 0.0474
# Epoch 38/50
# 64/64 [==============================] - 95s 1s/step - acc: 0.9741 - student_loss: 0.0683 - distillation_loss: 0.0167 - val_acc: 0.8250 - val_student_loss: 1.4734
# Epoch 39/50
# 64/64 [==============================] - 95s 1s/step - acc: 0.9762 - student_loss: 0.0720 - distillation_loss: 0.0157 - val_acc: 0.9375 - val_student_loss: 0.0539
# Epoch 40/50
# 64/64 [==============================] - 96s 2s/step - acc: 0.9711 - student_loss: 0.0800 - distillation_loss: 0.0165 - val_acc: 0.9125 - val_student_loss: 0.1063
# Epoch 41/50
# 64/64 [==============================] - 94s 1s/step - acc: 0.9689 - student_loss: 0.0780 - distillation_loss: 0.0152 - val_acc: 0.9438 - val_student_loss: 0.2048
# Epoch 42/50
# 64/64 [==============================] - 97s 2s/step - acc: 0.9712 - student_loss: 0.0752 - distillation_loss: 0.0164 - val_acc: 0.9000 - val_student_loss: 0.0909
# Epoch 43/50
# 64/64 [==============================] - 93s 1s/step - acc: 0.9765 - student_loss: 0.0691 - distillation_loss: 0.0168 - val_acc: 0.8438 - val_student_loss: 0.5020
# Epoch 44/50
# 64/64 [==============================] - 94s 1s/step - acc: 0.9713 - student_loss: 0.0719 - distillation_loss: 0.0170 - val_acc: 0.9250 - val_student_loss: 0.3445
# Epoch 45/50
# 64/64 [==============================] - 93s 1s/step - acc: 0.9738 - student_loss: 0.0727 - distillation_loss: 0.0153 - val_acc: 0.8438 - val_student_loss: 0.5658
# Epoch 46/50
# 64/64 [==============================] - 96s 2s/step - acc: 0.9728 - student_loss: 0.0720 - distillation_loss: 0.0161 - val_acc: 0.8813 - val_student_loss: 0.1394
# Epoch 47/50
# 64/64 [==============================] - 93s 1s/step - acc: 0.9739 - student_loss: 0.0732 - distillation_loss: 0.0158 - val_acc: 0.8875 - val_student_loss: 0.1611
# Epoch 48/50
# 64/64 [==============================] - 94s 1s/step - acc: 0.9787 - student_loss: 0.0630 - distillation_loss: 0.0161 - val_acc: 0.8750 - val_student_loss: 0.5262
# Epoch 49/50
# 64/64 [==============================] - 94s 1s/step - acc: 0.9750 - student_loss: 0.0700 - distillation_loss: 0.0152 - val_acc: 0.8250 - val_student_loss: 0.1558
# Epoch 50/50
# 64/64 [==============================] - 94s 1s/step - acc: 0.9760 - student_loss: 0.0626 - distillation_loss: 0.0155 - val_acc: 0.9312 - val_student_loss: 0.3242

# %%
#@title Destiled model metrics evolution

plt.figure(1)  
# summarize history for accuracy  
plt.subplot(211)  
plt.plot(distiller_hist.history['acc'])  
plt.plot(distiller_hist.history['val_acc'])  
plt.title('model accuracy')  
plt.ylabel('accuracy')  
plt.xlabel('epoch')  
plt.legend(['train', 'valid'], loc='lower right')  
 # summarize history for loss  
plt.subplot(212)  
plt.plot(distiller_hist.history['student_loss'])  
plt.plot(distiller_hist.history['val_student_loss'])  
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'valid'], loc='upper right')  
plt.show()
plt.tight_layout()

# %%
#@title Destiled model metrics

print(distiller.metrics_names)
acc, loss = distiller.evaluate(x_test, y_test, verbose = 1) 
print('test loss = ', loss)
print('test accuracy = ',acc)
# Out:
# ['acc']
# 20/20 [==============================] - 0s 21ms/step - acc: 0.9087 - student_loss: 0.2924
# test loss =  0.2152668833732605
# test accuracy =  0.9086538553237915

# %% [markdown]
# # Summary of metrics

# %%
#@title Main model metrics

print("Main model total parameters : ", f"{model.count_params():,}")

loss, acc = model.evaluate(x_test, y_test, verbose = 1)
print('test loss = ', loss) 
print('test accuracy = ',acc)
# Out:
# Main model total parameters :  27,561,282
# 20/20 [==============================] - 2s 121ms/step - loss: 0.3280 - acc: 0.8974
# test loss =  0.3280426561832428
# test accuracy =  0.8974359035491943

# %%
#@title Reduced model metrics

print("Student model total parameters : ", f"{reduced_model.count_params():,}")

loss, acc = reduced_model.evaluate(x_test, y_test, verbose = 1)
print('test loss = ', loss)
print('test accuracy = ',acc)
# Out:
# Student model total parameters :  295,690
# 20/20 [==============================] - 0s 16ms/step - loss: 0.2983 - acc: 0.9087
# test loss =  0.29833731055259705
# test accuracy =  0.9086538553237915

# %%
#@title Destiled model 2 metrics

print("Destiled model total parameters : ", f"{distiller.count_params():,}")

acc, loss = distiller.evaluate(x_test, y_test, verbose = 1) 
print('test loss = ', loss)
print('test accuracy = ',acc)
# Out:
# Destiled model total parameters :  27,856,972
# 20/20 [==============================] - 0s 17ms/step - acc: 0.9087 - student_loss: 0.2924
# test loss =  0.2152668833732605
# test accuracy =  0.9086538553237915

# %%
#@title Destiled student model metrics

studiante = distiller.student

print("Destiled model total parameters : ", f"{studiante.count_params():,}")

loss, acc = studiante.evaluate(x_test, y_test, verbose = 1)
print('test loss = ', loss)
print('test accuracy = ',acc)
# Out:
# Destiled model total parameters :  295,690
# 20/20 [==============================] - 0s 19ms/step - loss: 0.2983 - acc: 0.9087
# test loss =  0.29833731055259705
# test accuracy =  0.9086538553237915

# %%
#@title Import model as TF.js

# !pip install tensorflowjs

import tensorflowjs as tfjs

# %%
#@title Save models as TF.js

tfjs.converters.save_keras_model(model, './teacher_model/')
tfjs.converters.save_keras_model(student_model, './student_model/')
